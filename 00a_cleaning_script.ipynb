# %%
import pandas as pd
import json

# Step 1: Load the Business Data and Extract Unique Business IDs
business_df = pd.read_csv("Original/Yelp_Businesses.csv")
unique_business_ids = set(business_df["business_id"].unique())  # Convert to set for fast lookup

# Step 2: Load Reviews and Identify Matching & Non-Matching Business IDs
matching_reviews = set()  # Store unique matching business IDs
non_matching_reviews = set()  # Store unique non-matching business IDs

with open("yelp_academic_dataset_review.json", "r", encoding="utf-8") as file:
    for line in file:
        review = json.loads(line.strip())  # Convert each line to a JSON object
        if review["business_id"] in unique_business_ids:
            matching_reviews.add(review["business_id"])
        else:
            non_matching_reviews.add(review["business_id"])

# Step 3: Print Results
print(f"Total Matching Business IDs: {len(matching_reviews)}")
print(f"Matching Business IDs: {matching_reviews}")

print(f"Total Non-Matching Business IDs: {len(non_matching_reviews)}")
print(f"Non-Matching Business IDs: {non_matching_reviews}")
# Out:
# Total Matching Business IDs: 52268
# Matching Business IDs: {'miCXkkSGD4qCPUCIb5DHPw', 'ui9XXukBp4SAjVnCEuiUFw', 'KnVtTqZoGJiKfkLMkSlilA', 'fWwfbeOmsMy-GUJjKlp70A', 'ex_afm5DwBHa0bYjBm4SLw', 'gB9c_OMjvGrn36XjHArAUQ', 'Z9Q1IgIPB64Um_BNWpWgCA', 'TCYDFBbn6oW3sTO9Ub2hCA', 'iEl0YfLbbUy0itEd2Eh7ow', '5vb5EPOdgUafr3ZP84Hbpw', 'sh-v0ZYemr5mKg_tXSrzpA', 'yU2A8BW0lqcIGTiw2mMwBA', 'qusR0idbnaSYbHWe_fIWZQ', '7VAI-FzLX2qkpovzSluVQQ', 'OOtMbkngmDcJrsfMlJzK9Q', 'Fg68C3AwFu74dXMhgX3qIw', 'kBt6_fX1pZzizIMXDtD7og', '6GePX4W6Cl8LD68zUq_MAA', 'k82r04xQpJ7u9Db_aHRJpQ', '8MH8dtz8pW4FG0zRxcRFbw', 'fz9ymU6xguSAdVjSdHBLDg', 'mI6IKRJ-Q0EsexiCF-C_Eg', 'oId0VeETbxUWL8ynfJ6nJw', 'Sf0nVVa5QH70-Zam4MfexA', '49ES_VGv2UlXCFe2m466hQ', 'pHzTrxnY6mzh_rm86GDFqw', 'kbTVAHUbvK-SLFUvsRQKAg', 'kXIgc8v-OobCNYNAIE5Vrg', 'KRKqh3DK7sYanI7O8_3YLA', '6H1L78-SrSOLUqdV7FBaUA', 'DZYSb9amfB3EAh1IdwtbEA', 'l_FhL-_U2VqBIs4yfQb2_Q', 'fPVw_wHn85lccdTyMrcsZQ', 'T6c7iPO8Y4t_GQiyevZbiQ', 'NkDRMO8n4FHQLnWxbfstXQ', 'U37i8ZW0mA-A18N2Vpt9Yw', 'mhI_Ph26WPhbzX9Hs1lUtg', 'Kfd5R_3t4LI4el1D9YhkQw', 'vo9KLwtf_x1TpA9diT95zA', '5FuQbcHTF_I7PWJzhCMObw', 'd9vapPUlJCSSrltRRKO9ig', '00p_pZP6l7HQen1Yw7alkA', 'bWl3Tf7kgV1NU6bcshsTkw', 'kEBHUyNb5sCpah3QJuZK7A', 'AUgmziK-oyZqqlkFNx771g', 'UgnHg8cdrPqxJKD9MpHNPw', '7czFDmcXhqzcqvUnenNg6w', 'ztnxoNY4a3EOXkCQVAx4wg', 'g_66Ez_k8XNe1p71HLkecQ', 'aAmxfIA4VH7btp4lbr_P2A', 'pmRnKZ_xggQliQfJEIqXLQ', 'VHn9quq6LQftvSxOUfABjA', '2ZCdhEN_VcuVXNFYj0aXhw', 'dQXxeDOOYGuZeblUmP6oiw', 'crBJJE22QaFc2_Q49hbeLA', 'wvUhHEi-s9K8B95Ifi8RBg', 'WM3q-7scdPUei6fu4SJFYw', 'Hi4AgS-uR-lEOF4oZl546g', '_RRGOrzVgsEE4MlHHZE6iQ', 'BhVW7iBhCS3o3QgdKnQFag', 'Z5b1Me1YBZGQAxIx62vmqg', 'eSDTvyRCufzOBh-k_79gdg', '3LCIlNi_61V3mEGVs4IRqA', 'icp_IKE9zIkAqAucyS1vTA', 'ISFFAMis6f9ozFO2MHnuDQ', '2PmIhlF_5BHcRsVZsCtM0w', 'sowUp382s8UC3D6zvYCB8w', 'i32_0bfMEpQxV_q556R6kA', 'dK10D96iGeHuTQzR8aG90Q', 'JDBjHAYQozrnkaph5XQTTg', 'YPO3NLr89k2mSNgYcPoRrg', 'mf7M1IxaoCRoM4-jJsyblQ', 'UnBgLQYMzt-lWwIxHc_f6g', 'zLD-CFRdLV9Jr-GWL7gwPw', '4JV297fM7vuO-AYukVbqow', 'PIedZfXVCr820lB1bTHlMw', 'AmwIuW10EwmbTwuVEVTN7A', 'ttenaAAadxy5L-2oDR1ztQ', 'xzXcBF-2_JmIlfqYzxM9nw', 'XXaLhPTq4S93GhkhjqozsA', 'cpLRN_Ze8BowhfSx5_urWQ', '3LrDBhnsP4vj-Hsv7zYymA', 'jo37YLQJyWhuKBdjlKpoAw', 'hZtDA2MptLT7zdhDQ5bKRQ', 'g-Q7m7G3Xrez_Vc2T4wqNQ', 'oKvzmVhA1dKf-UARX4EpzQ', '7BrLqgURYEgCRyoNoo9TrQ', 'muFSb1eCiT2ufKSzJrN4vw', 'pt1E51u1aJUA9H7VWiMpFw', 'eRnCmPc6TTbNK-Zs0jgYPA', 'zmuecq9VaeLZDdMXP871VQ', 'RFYlmTjgwhOsm7qJwW1G9w', 'R8-iNVaAd0xLPes8oAQ6Rw', 'psG_tTwM0Wcddk9cW7yw_Q', '-0i2KNr7WrCsDF5m0IViJg', 'AjduhgGB3DxBApfFccRIaw', 'SPfxKVRdrAM41uuIJjIQCQ', 'gZxZpb21YNjCIYg5_yy6xA', 'djj8qE6hQjSeyEt9T2H_dg', 'fs6f7Esb6InIC2QhwWi_hQ', 'zBpNvn_gH6T9KYTZCvqtxg', 'ZrUwYQES9u-8Fpldsvzsaw', 'PWGcA2s9sf4iMb4dcLz6Hg', 'UNGcOPIrWpreWUitaC02Xg', 'h19Jm-9cxv48N2gUhFFdvg', 'K5lj6JVNQb7ayDEBsU-4HA', '28Q07HstcPUjj_WaqI-8DA', 'MOSR1deJTGCSK8PzoRT2Hw', 'ZnRFh390K4vgTvbNKi59GA', 'D4N3kguo363wDH0S1yp6uQ', 'Q9knOlfU9ppR1HhtK8r7qA', 'qBIv-Q0bAOYyRSXZbtOtng', 'nyU4OrNGq-rme9lHvtIVIA', 'q9SbiQ42KZ7yvEYZhYlttA', 'WtC6tR6Wq9g_vguMalpliQ', 'JbyHeQe-Ifn3FPpp0LATwA', '0COlL5IKRu5sdWIsEiQAZg', 'O76kDVYNag6w7VJVd69m3A', 'fts8YQMC69xs0SyisM4AJg', 'fOTDwlJdgwuGTbYrjt_88Q', 'k8SvXoV6TFMTfrRsvzJ6uA', '647ZcTYCzk9a-wfoK2Uk3w', '64i1xdiU1Wvo1Cuu0erFGA', 'Xxz8IhhHqrgwrty7ww4jDQ', 'P0yKtQ4cFjNTY1X2CIdzBw', 'bUL0ccO-bbQICKHImPUyJQ', 'P-a6WMxnBncXP4ZnFXeYww', 'JK8Wtzz_lK6edjOU1uLT5w', 'HsTAssMCw5N_f3fxsdVOnw', 'Nc1bAWIlGgpauU6pClO-Nw', 'THJ0i8yRyx1OfvzLsJXgng', '2I0GtFcDwEQv6-fruMxNng', '6aPXOXi8h1m58hihgi2dvw', 'BnprLJ4Lr33--YjTmgk9Zg', 'yZYx6GiDN9pc8hutC_1qIg', '0exAfLiQVzBZGlJjtzAw4Q', 'eaIGBizaDyAPun8gbpxrwA', 'UkNhUEyGT81qK3HaKwLsvw', '2pBNVsJo3a3CPbInUu9lvQ', 'T4v7qgTIhDFoDYxTMus5Yw', 'Jd5QJYs-2lP_Nu-fjdC_hw', 'JQQEuG3nAMNJ9EOZRD33yw', 'WRckwZQdiw8QKh0UY-wJnA', 'lNlbPEQOZaBWtv_ynQGYNg', 'FqvItVbM-G2AoQeWC-EBMw', 'Rb26mGIH6BHAoGl6OksJPQ', 'GczZuKVQtsWLUgchZW9L-A', 'WLaT4_8EgunV0UXks3Qukw', 'wjUlOsBLLnxpprgI-sSiDA', 'NAteFFdicyMGCJGVW0BGKQ', 's5K7M7BBFDbFkvv14XwkgA', 'Z9kSxZ24MQ_8IBXb2epknw', 'IfU9K5Qrln8I7M8dZI_FVw' ...
# Total Non-Matching Business IDs: 98078
# Non-Matching Business IDs: {'lmRr6WjnhfItBZWZEdAfsQ', 'PP2ukFk8O687UQoUxMczSg', 'Shywx8-jqV1IxwLaefbcSA', '2zNT_0JAfAGxKW02J9QSiw', 'KHfg4owPCovQMWZ_uAIKwQ', 'PB6Rks0PSxWvaJ6vl_KcRQ', 'NoI52tsk5G5hZImZud2gbw', '6CvHU5uW6PIvzV67XD3tFw', '-zMb1wf7fazFNISZ8wxYRA', '1ovn6V37WDKJVqZ83ahk1g', '6fjHfzOQyhE4Cv8sJ_nzEA', 'WAMa_7erHFDYHtk3CtzhWQ', 'AGrBi-9CyyHGgLuP0M9trw', 'chjIM0d2a0LMlFwk6ccSDQ', '9YutzhnWxM7aTi8q0mdC3Q', 'aTpaOvF1FFGj8t_5U2_kHA', 'nx8a-0rWqmkQDtYtXK0nhg', 'QlO0E5fdvxWnb3mIgCh0yw', 'TZbMjVdlnUy1ZbB0WvZ32A', 'LyBICXapnJkLMaQPMTcJSg', 'QcHY_QuVZ078kuAC-GtlEw', 'YulEN9LO_-5nKItFR-LfOA', 'DLFr4-ByVg4C1wyhSpFoMA', 'o2uKA4DbVaM2Daha0lVX9w', '6bHFNCR1qqL_Mwdd6bj7pw', 'OHjKaP1BpwT-JSq9emCrwQ', 'iNWuHqMXsAygtYpej6zXhw', 'p5nsH3stC9TlwF4W3Os71Q', 'IB3_LaG9T1RqbK__x97gBQ', 'pVQ8MYQhSe98GfXHXwtREA', 'goI3MrJIPJxknQdKtFkkGw', 'nC9lhqf-diWyu5ejHWOz-w', 'PmYILphI46sDCAxkDZARjQ', '6KeZQhjKhzHCvUZG2OuVjQ', 'SclqCJNIkJvyLfT6CB7aWw', '-KZO4eNu5lwPmRLQSci7Tg', 'ueVgsH6YXcXgSa1yCVinVA', 'O7MbaNGWD870TBkjpxY9IQ', 'C40QrOPVa9ywZzca4gPXrA', 'ELBlFMRas4J0s-hOUGR4bA', 'JhAyG4TYH9sFGVGhxjHsSQ', 'uBhAftKICxFoJAliQRQEbA', 'MkeTrOpWWt46oNTj2qM6lw', 'xt1wRm1Ti-P6cF2rAY1_XA', 'XJ_l37XQrG-tgsTqci_xBg', 'RMD5mNJgyQ1FGO_5YDCrzA', '8XKjKN7SR5f448wy8OjtUg', 'inNXI7gk_if9oDH8CJULGg', 'cxQu5FGbXD4qHfdQZ9HAbA', 'tOXSEWjZ9XjTkl1NU3uAcw', 'h0UrquZ3rvG9z5_vaigqeg', 'I-sOjEN3lux81L_ol3cYFQ', 'R3dFk70yrvHMKTgOCBDPqQ', '6x6k00x3QMj22aicPEQuHQ', '-yvKJy3j1g4LYtDKx1PqNw', 'TP3pTbusk-zHZFXLSSnwmQ', 'rmqoJVwujDuCe6cOgdf36Q', 'km3eDGqOMxygC3UviNxseg', '_AyG0N2WMeg3ltPuhV7N0Q', 'bCVZtOVlxufGZLsOg2m0vA', 'g7YZ19bGZqq-WdbwgUoMkw', 'tzvbWBUJJ2rPBJTo_OyTVw', '3zjlKKC3CLFqzT0OUG-mKA', '30SveE-LXZ6a77oqBBBFEw', 'sD0rLX0E7NKNyZ9c_cXrUg', 'ATbojITCoQDhKqH8RswaaA', 'SP5oZ5avHVRRQuPVyBCa0g', '1pJOnROoaVL9nxwzqz6dTQ', '5VIP5rsbra0RNotNN0jufg', 'HFmLKshpSesBsPPU7zGVSg', 'AeET2x8f7vLSZl2upH_R-A', 'FkyuGxycBYR0kGc2JP_t9Q', 'gPNOh57PRAQIWcALs91uCw', 'zKGDsicxJW_27aSdceUb-g', 'j7eBypL-DlgQjxPGjtvxvg', 'lcisvzKfw3g04-sIchUkiA', 'hG8GNWkp19ZMJZ9Q55Hd1A', 'qNXgn3rjqQUOWGSocspuJA', 'QPH7nrObv7TmTHFHAK9sjw', 'gZNgbJfETXO_9uHN-kpwLQ', 'cs853C-WHtQx6wkvBAS_CA', 'hvDvdmecT-rI0k8XbiRvdg', 'tYLjTCs1s0LgmjCsPiBfKQ', '_2k35u1zef_wGuENTVb9iQ', 'i64vp0F852FPR8vw8HJn1A', 'hpgxh_tFNGbAUS8uz_sqZg', 'Jy5SeySFhUjNbAhFvb4GpA', 'XMQoWCrD-sj6aoM1RYeT4g', '8OirL-hbzxuvwGLke6HirQ', 'vGqpBERulBGf-v2tfVvHhw', 'SsshnnpJYrX4SEbyyCGWWQ', 'Ck7AjT6tEXzuKBRrjwNYUA', 'lFCjDyvMRL_VwqMzs5_5Rw', 'kh26Z_S8873OPzqApt76KA', '3tX0CduxNIHgrxr6Toairw', 'WpdZOxz9O4rRuAp4LcL_ZA', 'DAbOzCH5DjH5E7XQbRbywQ', '-4G38D90ZA4cmU95nRIjLQ', 'WCvC2yq3BPK2AN0cfk9adw', 'iPuUDOwZKlGewjaDVo9kOg', 'P9B6PuQtlcOor4baXaaBSg', 'WtB8LaWoMtTTj7fh4rzpVw', 'KJl4Cp1N1IALj-SkSkE5HA', 'BDNYZRgJj8_k6iwNLqK8hQ', 'Ge6Ta-4SF1t97-VWoiQLSA', 'flqe3EA6q_WALHRM99dhAQ', 'altkuj5DHIOveAydxXPs8Q', 'JMIuSjigQyn9Lnsu3EuyxQ', 'jjJRj3vBY1Bda2OMxDtdSg', 'IhzuSD9lCOBnOaCtAwGtIw', 'SoOstg_WyTkfTCS0tBg32A', '9LvA0NUSftDs13sADDRKQA', 'FJaTierDJxsT8XxCrrfCug', 'y6Yh9ezGQIRSA7Vg7yysUA', 'El1_Myk6dJ2JSapIsONsxw', 'vjiUIxl03Y5mkkkAxXqi_Q', 'YfRM0FCfk0UP3xyX8cd9Iw', 'FIqyOT97V9qZErlltQjqTg', 'wROeyLOm6vL8qyXD6zTOlA', '4i-vytkm3K-l3J5hpeIBCw', '0gO3jPLdv8xBi55BG2CsmA', 'wDbXpSDZ7CCoR6N4UF2Uwg', 'mgkOYdOiZ1j-vM8PWoOtag', 'S96NERlv84CUHHHtnRW6IA', 'jYdim8o7uqTINRwMTdZFdw', 'vwMfNmgvYFeT-uC7bd6TMg', 'I4GXcmX8XVIdKKVIxGRQSw', 'etCUkzk02xjyNMyo6hn3eA', 'E4Jia_6rDnYKEKoxG4MxJQ', 'hcMrQDbdBdx3U_sOpapq-Q', 'sTrHe42oUrfyuC6i9OHD2g', 'Qt1rf5cUZMrDYtBxFlPZRQ', 'c7WZXqCRHWSJWEkD6Fbswg', 'Cb4wRZbTU1GUgoNYWTRi9Q', '2cEJyupw_tE2P7vPMm13Eg', 'rWe-YRWP2PZ4N3mhniOXNg', 'LR6rFmqGRDFRKbkGrPQBKg', 'qDCTg0izNlCMph9iH6riow', '9SJ0UHzBsO_h93SJc42VMQ', '9ardKrEo67b--N3XIEI4xQ', 'dLRbHKbn5Aj9dwgO3Kc-bg', 'BBNNlNmj0R2ZGmlGX99Q_g', 'sJA7kdZcvswuWQEmKZYnIg', 'Kx6kRvz-qqhpLdZtcTXiEQ', '8fV6orH4Oewan1BAAtCQyg', '410SzJMr27T3wUusKW890A', 'LQIoQ4ZOXFg2iCb529b_Cg', 'F02ycUVf4heHonBXO-uw1A', 'tt5NnIvOQ4GMxOU0rLSCxA', 'LunsiYDUH-LCZMvcldM1LA', '2gikq-ETMz-rtit02Ji9dw', 'bzn-j9LEP3F5p-8WSgiTzQ', '66RyA40aGak04yq3Be6 ...

# %%
# Load the filtered CSV file and count the number of rows (reviews)
filtered_reviews_df = pd.read_csv("Filtered_Yelp_Reviews.csv")

# Print the total number of reviews
print(f"Total Reviews in Filtered_Yelp_Reviews.csv: {len(filtered_reviews_df)}")
unique_review_business_ids = set(filtered_reviews_df["business_id"].unique())
print(f"Total Unique Business IDs in Review: {len(unique_review_business_ids)}")
# Out:
# Total Reviews in Filtered_Yelp_Reviews.csv: 1625648
# Total Unique Business IDs in Review: 20074

# %%
import pandas as pd
import json

# Extract unique business IDs from both datasets
filtered_reviews_df = pd.read_csv("Filtered_Yelp_Reviews.csv")
business_df = pd.read_csv("Original/Yelp_Businesses.csv")
filtered_review_business_ids = set(filtered_reviews_df["business_id"].unique())
business_ids = set(business_df["business_id"].unique())

# Find matching business IDs
matching_business_ids = filtered_review_business_ids.intersection(business_ids)

# Print results
print(f"Total Business IDs in Yelp_Businesses.csv: {len(business_ids)}")
print(f"Total Business IDs in Filtered_Yelp_Reviews.csv: {len(filtered_review_business_ids)}")
print(f"Total Matching Business IDs: {len(matching_business_ids)}")
# Out:
# Total Business IDs in Yelp_Businesses.csv: 52268
# Total Business IDs in Filtered_Yelp_Reviews.csv: 20074
# Total Matching Business IDs: 20074

# %%
import pandas as pd
import json

# %%
df = pd.read_csv("Original/Filtered_Yelp_Reviews.csv")

# Display the first 5 rows
print(df.head())

# Display the data types of each column
print(df.dtypes)
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 2  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 3  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
# 4  JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A  04UD14gamNjLY0IDYVhHJg
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    3.0       0      0     0
# 2    5.0       1      0     1
# 3    4.0       1      0     1
# 4    1.0       1      2     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# 2  Wow!  Yummy, different,  delicious.   Our favo...  2015-01-04 00:01:03
# 3  Cute interior and owner (?) gave us tour of up...  2017-01-14 20:54:15
# 4  I am a long term frequent customer of this est...  2015-09-23 23:10:31
# review_id       object
# user_id         object
# business_id     object
# stars          float64
# useful           int64
# funny            int64
# cool             int64
# text            object
# date            object
# dtype: object

# %%
# Convert 'date' column to datetime
df['date'] = pd.to_datetime(df['date'])

# Verify the change
print(df.dtypes)
# Out:
# review_id              object
# user_id                object
# business_id            object
# stars                 float64
# useful                  int64
# funny                   int64
# cool                    int64
# text                   object
# date           datetime64[ns]
# dtype: object

# %%
# Convert columns to string type
df['review_id'] = df['review_id'].astype(str)
df['user_id'] = df['user_id'].astype(str)
df['business_id'] = df['business_id'].astype(str)

# Verify the change
print(df.dtypes)
# Out:
# review_id              object
# user_id                object
# business_id            object
# stars                 float64
# useful                  int64
# funny                   int64
# cool                    int64
# text                   object
# date           datetime64[ns]
# dtype: object

# %%
# Save the cleaned dataframe to a new CSV file
df.to_csv("Cleaned_Filtered_Yelp_Reviews.csv", index=False)

print("File saved as Cleaned_Filtered_Yelp_Reviews.csv")
# Out:
# File saved as Cleaned_Filtered_Yelp_Reviews.csv

# %%
business_df = pd.read_csv("Original/Cleaned_Yelp_Businesses_v2.csv")

# %%
business_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52268 entries, 0 to 52267
# Data columns (total 37 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   business_id           52268 non-null  object
#  1   name                  52268 non-null  object
#  2   address               51825 non-null  object
#  3   city                  52268 non-null  object
#  4   state                 52268 non-null  object
#  5   postal_code           52247 non-null  object
#  6   latitude              52268 non-null  float64
#  7   longitude             52268 non-null  float64
#  8   stars                 52268 non-null  float64
#  9   review_count          52268 non-null  int64
#  10  is_open               52268 non-null  int64
#  11  categories            52268 non-null  object
#  12  hours_Thursday        44429 non-null  object
#  13  hours_Friday          44644 non-null  object
#  14  hours_Wednesday       43742 non-null  object
#  15  hours_Tuesday         41783 non-null  object
#  16  hours_Monday          38967 non-null  object
#  17  hours_Saturday        43525 non-null  object
#  18  hours_Sunday          37703 non-null  object
#  19  accepts_credit_cards  45531 non-null  object
#  20  parking               44873 non-null  object
#  21  price_range           52268 non-null  float64
#  22  bike_parking          52268 non-null  bool
#  23  takeout               47628 non-null  object
#  24  wifi                  37712 non-null  object
#  25  delivery              52268 non-null  bool
#  26  outdoor_seating       43639 non-null  object
#  27  reservations          42857 non-null  object
#  28  good_for_groups       41419 non-null  object
#  29  alcohol               19643 non-null  object
#  30  attire                38955 non-null  object
#  31  noise_level           34808 non-null  object
#  32  table_service         19722 non-null  object
#  33  happy_hour            13007 non-null  object
#  34  drive_thru            5868 non-null   object
#  35  smoking               3443 non-null   object
#  36  byob                  4211 non-null   object
# dtypes: bool(2), float64(4), int64(2), object(29)
# memory usage: 14.1+ MB

# %%
business_df_updated_hours = pd.read_csv("Original/Cleaned_Yelp_Businesses_v2.csv")

# Function to process hours and convert to time format
def process_hours(hours):
    if pd.isna(hours) or hours.strip() == "":  # Handle missing or empty values
        return "N/A", "N/A", "N/A"
    try:
        open_time_str, close_time_str = hours.split('-')

        # Convert "7:0" format to proper "07:00"
        open_time = pd.to_datetime(open_time_str, format="%H:%M").time()
        close_time = pd.to_datetime(close_time_str, format="%H:%M").time()

        # Convert to hours open (handle overnight closures)
        open_hours = int(open_time_str.split(":")[0]) + int(open_time_str.split(":")[1]) / 60
        close_hours = int(close_time_str.split(":")[0]) + int(close_time_str.split(":")[1]) / 60

        if close_hours < open_hours:
            close_hours += 24  # Adjust for overnight closures

        hours_open = close_hours - open_hours

        return open_time.strftime("%H:%M"), close_time.strftime("%H:%M"), round(hours_open, 2)
    except:
        return "N/A", "N/A", "N/A"

# Process each day's hours column in the original business_df
for day in ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]:
    column_name = f"hours_{day}"
    if column_name in business_df_updated_hours.columns:
        business_df_updated_hours[f"{day}_opening"], business_df_updated_hours[f"{day}_closing"], business_df_updated_hours[f"{day}_hours_open"] = zip(
            *business_df_updated_hours[column_name].apply(process_hours)
        )

# Drop the original hours columns in the original dataframe
business_df_updated_hours = business_df_updated_hours.drop(columns=[f"hours_{day}" for day in ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]])

# Select relevant columns for review
columns_to_review = ["business_id", "name"] + [f"{day}_opening" for day in ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]] + \
                    [f"{day}_closing" for day in ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]] + \
                    [f"{day}_hours_open" for day in ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]]

# Print the first 10 rows for review
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 1000)
print(business_df_updated_hours[columns_to_review].head(10))

# Save the cleaned dataset
business_df_updated_hours.to_csv("Cleaned_Yelp_Businesses_v3.csv", index=False)

print("Cleaned data saved as Cleaned_Business_Data.csv")
# Out:
#   business_id             name                            Monday_opening Tuesday_opening Wednesday_opening Thursday_opening Friday_opening Saturday_opening Sunday_opening Monday_closing Tuesday_closing Wednesday_closing Thursday_closing Friday_closing Saturday_closing Sunday_closing Monday_hours_open Tuesday_hours_open Wednesday_hours_open Thursday_hours_open Friday_hours_open Saturday_hours_open Sunday_hours_open
# 0  MTSW4McQd7CbVtyjqoe9mw              St Honore Pastries  07:00          07:00           07:00             07:00            07:00          07:00            07:00          20:00          20:00           20:00             20:00            21:00          21:00            21:00          13.0              13.0               13.0                 13.0                14.0              14.0                14.0
# 1  CF33F8-E6oudUQ46HnavjQ                  Sonic Drive-In  00:00          06:00           06:00             06:00            09:00          09:00            08:00          00:00          22:00           22:00             22:00            00:00          22:00            22:00           0.0              16.0               16.0                 16.0                15.0              13.0                14.0
# 2  k0hlBqXX-Bt0vf1op7Jr1w           Tsevi's Pub And Grill    N/A            N/A             N/A               N/A              N/A            N/A              N/A            N/A            N/A             N/A               N/A              N/A            N/A              N/A           N/A               N/A                N/A                  N/A                 N/A               N/A                 N/A
# 3  bBDDEgkFA1Otx9Lfe7BZUQ                  Sonic Drive-In  00:00          06:00           06:00             06:00            06:00          06:00            06:00          00:00          21:00           21:00             16:00            16:00          17:00            21:00           0.0              15.0               15.0                 10.0                10.0              11.0                15.0
# 4  eEOYSgkmpB90uNA7lDOMRA           Vietnamese Food Truck  11:00          11:00           11:00             11:00            11:00          05:00            15:00          14:00          14:00           14:00             14:00            14:00          10:00            18:00           3.0               3.0                3.0                  3.0                 3.0               5.0                 3.0
# 5  il_Ro8jwPlHresjw9EGmBg                         Denny's  06:00          06:00           06:00             06:00            06:00          06:00            06:00          22:00          22:00           22:00             22:00            22:00          22:00            22:00          16.0              16.0               16.0                 16.0                16.0              16.0                16.0
# 6  0bPLkL0QhhPO5kt1_EXmNQ            Zio's Italian Market  10:00          10:00           10:00             10:00            10:00          10:00              N/A          18:00          20:00           20:00             20:00            20:00          20:00              N/A           8.0              10.0               10.0                 10.0                10.0              10.0                 N/A
# 7  MUTTqe8uqyMdBl186RmNeA                        Tuna Bar    N/A          13:30           13:30             13:30            13:30          13:30            13:30            N/A          22:00           22:00             22:00            23:00          23:00            22:00           N/A               8.5                8.5                  8.5                 9.5               9.5                 8.5
# 8  ROeacJQwBeh05Rqg7F6TCg                             BAP  11:30          11:30           11:30             11:30            11:30          11:30              N/A          20:30          20:30           20:30             20:30            20:30          20:30              N/A           9.0               9.0                9.0                  9.0                 9.0               9.0                 N/A
# 9  WKMJwqnfZKsAae75RMP6jA  Roast Coffeehouse and Wine Bar  08:00          08:00           08:00             08:00            08:00          08:00            10:00          18:00          18:00           18:00             18:00            18:00          18:00            17:00          10.0              10.0               10.0                 10.0                10.0              10.0                 7.0
# Cleaned data saved as Cleaned_Business_Data.csv
